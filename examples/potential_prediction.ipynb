# %% [markdown]
# ### Interatomic potential
# An example notebook for constructing a high-dimensional neural network potential (HDNNP).

# %%
# !gpustat

# %%
# from utils import set_env
# set_env('.env')

# %%
import os
os.environ["JAX_ENABLE_X64"] = "1"
os.environ["JAX_PLATFORM_NAME"] = "cpu" 
os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"] = "false"

# %%
from jaxip.datasets import RunnerStructureDataset
from jaxip.potentials import NeuralNetworkPotential
from ase.visualize import view

# %%
# Atomic data
structures = RunnerStructureDataset("GRN/input.data")

# structures = [structures[i] for i in range(10)]
structure = structures[0]

# %%
# Potential
nnp = NeuralNetworkPotential.create_from("GRN/input.nn")

# nnp.save()
nnp.load()

# %%
view(structure.to_ase_atoms() * (3, 3, 2), viewer='x3d')
# Out:
# <html>
#
#  <head>
#
#   <title>ASE atomic visualization</title>
#
#   <link rel="stylesheet" type="text/css"
#
#    href="https://www.x3dom.org/x3dom/release/x3dom.css">
#
#   </link>
#
#   <script type="text/javascript"
#
#    src="https://www.x3dom.org/x3dom/release/x3dom.js">
#
#   </script>
#
#  </head>
#
#  <body>
#
#   <X3D>
#
#    <Scene>
#
#     <Transform translation="0.77 1.21 0.12">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.47 7.37 0.01">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
# ...

# %%
# %time total_energy = nnp(structure)
total_energy
# Out:
# CPU times: user 66.3 ms, sys: 0 ns, total: 66.3 ms
# Wall time: 42.8 ms
# Array(-8.16495476, dtype=float64)

# %%
# %time force = nnp.compute_force(structure)
force
# Out:
# CPU times: user 44.1 ms, sys: 188 µs, total: 44.3 ms
# Wall time: 42.1 ms
# {'C': Array([[-3.33095901e-02, -3.08686756e-02,  1.50103923e-02],
#         [-4.59666550e-03,  1.18638966e-02, -4.76944027e-04],
#         [-7.47202430e-04,  2.98190862e-03,  2.71966569e-02],
#         [-2.72367522e-02,  2.73160152e-02, -1.34700639e-02],
#         [ 6.62050489e-03, -8.46516062e-03,  7.87529862e-05],
#         [-2.97010690e-02, -2.68040895e-02,  1.30132372e-02],
#         [-1.59080997e-02, -2.04540268e-02,  1.81782730e-02],
#         [ 3.15810964e-02,  1.08764395e-02,  1.49533711e-03],
#         [-1.57766845e-02, -1.74782965e-02,  8.57392140e-03],
#         [-1.85346119e-02,  3.91322970e-02,  8.85499548e-03],
#         [-3.57302371e-03, -1.00013427e-02,  1.78669346e-03],
#         [ 1.02864671e-02, -6.64934888e-03, -1.74041986e-02],
#         [ 1.88025329e-02, -1.13072162e-02, -9.24435630e-03],
#         [ 6.75464934e-03,  1.19458456e-02, -9.41931456e-03],
# ...
